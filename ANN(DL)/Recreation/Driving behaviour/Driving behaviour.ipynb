# %% [markdown]
# Experimental

# %%
# Import required libraries
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
from pandas import  *
from numpy import *
from seaborn import *
from matplotlib.pyplot import *
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
df=read_csv('train_motion_data.csv')

# %%
x=df.iloc[:,:-2]

# %%
x.columns
# Out:
# Index(['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY', 'GyroZ'], dtype='object')

# %%
y=df[['Class']]

# %%
y
# Out:
#        Class
# 0     NORMAL
# 1     NORMAL
# 2     NORMAL
# 3     NORMAL
# 4     NORMAL
# ...      ...
# 3639    SLOW
# 3640    SLOW
# 3641    SLOW
# 3642    SLOW
# 3643    SLOW
#
# [3644 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier(n_estimators=500)
r.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
r.score(x_train,y_train)
# Out:
# 1.0

# %%
r.score(x_test,y_test)
# Out:
# 0.4089935760171306

# %% [markdown]
# Try DL

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.utils import to_categorical

# Assuming your data is stored in a DataFrame named 'data'

# Preprocess data if necessary (e.g., scaling, encoding labels)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_train)

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_train)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_encoded, test_size=0.2, random_state=42)

# Define your deep learning model
model = Sequential([
    Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(len(label_encoder.classes_), activation='softmax')  # Output layer with softmax activation for multi-class classification
])

# Compile the model with sparse categorical cross-entropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=500, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/500
# c:\Users\debna\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3736 - loss: 1.0983 - val_accuracy: 0.4142 - val_loss: 1.0875
# Epoch 2/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4415 - loss: 1.0692 - val_accuracy: 0.4100 - val_loss: 1.0738
# Epoch 3/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4973 - loss: 1.0440 - val_accuracy: 0.4100 - val_loss: 1.0676
# Epoch 4/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4940 - loss: 1.0249 - val_accuracy: 0.4435 - val_loss: 1.0533
# Epoch 5/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4675 - loss: 1.0248 - val_accuracy: 0.4561 - val_loss: 1.0470
# ...

# %% [markdown]
# Shit ! accuracy is just 30%

# %%
input_data = [[0.2383908,0.029413342,0.33282852,0.0012217305,-0.015042556,0.023060163]]

# Convert input data to numpy array if necessary
input_data = array(input_data)

# Preprocess input data if necessary (e.g., scaling)
# Make predictions
predictions = model.predict(input_data)

# Decode predictions back to string labels
predicted_labels = label_encoder.inverse_transform(predictions.argmax(axis=1))


predicted_labels
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# array([[2]], dtype=int64)

# %%
# Define a dictionary mapping integer labels to string labels
class_mapping = {2: 'AGGRESSIVE', 0: 'SLOW', 1: 'NORMAL'}

# Convert the predicted numeric labels to string labels using the class mapping
predicted_labels = [class_mapping[label] for label in predictions.argmax(axis=1)]

predicted_labels
# Out:
# ['AGGRESSIVE']

# %%
input_data = [[0.8176316,1.2116989,1.4953814,-0.017562376,0.040317107,0.030466905]]

# Convert input data to numpy array if necessary
input_data = array(input_data)

# Preprocess input data if necessary (e.g., scaling)
# Make predictions
predictions = model.predict(input_data)

# Decode predictions back to string labels
predicted_labels = label_encoder.inverse_transform(predictions.argmax(axis=1))


predicted_labels
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# array([2], dtype=int64)

# %%
# Define a dictionary mapping integer labels to string labels
class_mapping = {2: 'AGGRESSIVE', 0: 'SLOW', 1: 'NORMAL'}

# Convert the predicted numeric labels to string labels using the class mapping
predicted_labels = [class_mapping[label] for label in predictions.argmax(axis=1)]

predicted_labels
# Out:
# ['AGGRESSIVE']
