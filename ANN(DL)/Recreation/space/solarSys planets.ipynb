# %%
# Import required libraries
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
from pandas import  *
from numpy import *
from seaborn import *
from matplotlib.pyplot import *
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
df=read_csv('Solarsysplanets.csv')

# %%
df
# Out:
#                               planet       mass  diameter  density  gravity  \
# 0           Small rocky hot(Mercury)     0.3300      4879     5427      3.7
# 1         Cloudy volcanic hot(Venus)     4.8700     12104     5243      8.9
# 2           Blue  water world(Earth)     5.9700     12756     5514      9.8
# 3              Red dusty small(Mars)     0.6420      6792     3933      3.7
# 4    Giant stormy gas giant(Jupiter)  1898.0000    142984     1326     23.1
# 5  Ringed giant gas majestic(Saturn)   568.0000    120536      687      9.0
# 6  Ice tilted big blue-green(Uranus)    86.8000     51118     1271      8.7
# 7            Blue windy big(Neptune)   102.0000     49528     1638     11.0
# 8              Dwarf icy tiny(Pluto)     0.0146      2370     2095      0.7
#
#    escape_velocity  rotation_period  length_of_day  distance_from_sun  \
# 0              4.3           1407.6         4222.6               57.9
# ...

# %%
df=df.drop(columns='surface_pressure')
df
# Out:
#                               planet       mass  diameter  density  gravity  \
# 0           Small rocky hot(Mercury)     0.3300      4879     5427      3.7
# 1         Cloudy volcanic hot(Venus)     4.8700     12104     5243      8.9
# 2           Blue  water world(Earth)     5.9700     12756     5514      9.8
# 3              Red dusty small(Mars)     0.6420      6792     3933      3.7
# 4    Giant stormy gas giant(Jupiter)  1898.0000    142984     1326     23.1
# 5  Ringed giant gas majestic(Saturn)   568.0000    120536      687      9.0
# 6  Ice tilted big blue-green(Uranus)    86.8000     51118     1271      8.7
# 7            Blue windy big(Neptune)   102.0000     49528     1638     11.0
# 8              Dwarf icy tiny(Pluto)     0.0146      2370     2095      0.7
#
#    escape_velocity  rotation_period  length_of_day  distance_from_sun  \
# 0              4.3           1407.6         4222.6               57.9
# ...

# %%
df.shape
# Out:
# (9, 20)

# %%
x=df.iloc[:,1:20]
x
# Out:
#         mass  diameter  density  gravity  escape_velocity  rotation_period  \
# 0     0.3300      4879     5427      3.7              4.3           1407.6
# 1     4.8700     12104     5243      8.9             10.4          -5832.5
# 2     5.9700     12756     5514      9.8             11.2             23.9
# 3     0.6420      6792     3933      3.7              5.0             24.6
# 4  1898.0000    142984     1326     23.1             59.5              9.9
# 5   568.0000    120536      687      9.0             35.5             10.7
# 6    86.8000     51118     1271      8.7             21.3            -17.2
# 7   102.0000     49528     1638     11.0             23.5             16.1
# 8     0.0146      2370     2095      0.7              1.3           -153.3
#
#    length_of_day  distance_from_sun  perihelion  aphelion  orbital_period  \
# 0         4222.6               57.9        46.0      69.8            88.0
# ...

# %%
y=df[['planet']]

# %%
y
# Out:
#                               planet
# 0           Small rocky hot(Mercury)
# 1         Cloudy volcanic hot(Venus)
# 2           Blue  water world(Earth)
# 3              Red dusty small(Mars)
# 4    Giant stormy gas giant(Jupiter)
# 5  Ringed giant gas majestic(Saturn)
# 6  Ice tilted big blue-green(Uranus)
# 7            Blue windy big(Neptune)
# 8              Dwarf icy tiny(Pluto)

# %%
'''from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)
'''
# Out:
# 'from sklearn.model_selection import train_test_split\nx_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)\n'

# %%
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier(n_estimators=200,random_state=1)

# %%
r.fit(x,y)
# Out:
# C:\Users\debna\AppData\Local\Temp\ipykernel_8744\2591809438.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   r.fit(x,y)
# RandomForestClassifier(n_estimators=200, random_state=1)

# %%
r.score(x,y)
# Out:
# 1.0

# %%
pred=r.predict([[0.014,2350,2100,0.6,1.5,-150,150,5900,4440,7380.9,90500,4.6,17,0.2,122,-220,4,0,0]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
pred
# Out:
# array(['Dwarf icy tiny(Pluto)'], dtype=object)
