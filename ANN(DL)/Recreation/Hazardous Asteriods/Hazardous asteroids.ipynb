# %%
# Import required libraries
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
from pandas import  *
from numpy import *
from seaborn import *
from matplotlib.pyplot import *
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
df=read_csv('orbits - orbits.csv')

# %%
df
# Out:
#         Object Name  Epoch (TDB)  Orbit Axis (AU)  Orbit Eccentricity  \
# 0          433 Eros        57800           1.4579              0.2226
# 1        719 Albert        57800           2.6385              0.5479
# 2        887 Alinda        57800           2.4787              0.5671
# 3      1036 Ganymed        57800           2.6628              0.5338
# 4         1221 Amor        57800           1.9191              0.4356
# ...             ...          ...              ...                 ...
# 15630    (2017 CX1)        57800           1.4096              0.2946
# 15631    (2017 CO5)        57789           2.2612              0.4429
# 15632    (2017 CP5)        57800           1.5131              0.3275
# 15633    (2017 CR5)        57793           1.8815              0.4646
# 15634    (6344 P-L)        57800           2.8043              0.6672
#
#        Orbit Inclination (deg)  Perihelion Argument (deg)  \
# 0                      10.8277                   178.8050
# ...

# %%
df.isnull().sum()
# Out:
# Object Name                                 0
# Epoch (TDB)                                 0
# Orbit Axis (AU)                             0
# Orbit Eccentricity                          0
# Orbit Inclination (deg)                     0
# Perihelion Argument (deg)                   0
# Node Longitude (deg)                        0
# Mean Anomoly (deg)                          0
# Perihelion Distance (AU)                    0
# Aphelion Distance (AU)                      0
# Orbital Period (yr)                         0
# Minimum Orbit Intersection Distance (AU)    0
# Orbital Reference                           0
# Asteroid Magnitude                          1
# Classification                              0
# Hazardous                                   0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Object Name                                 0
# Epoch (TDB)                                 0
# Orbit Axis (AU)                             0
# Orbit Eccentricity                          0
# Orbit Inclination (deg)                     0
# Perihelion Argument (deg)                   0
# Node Longitude (deg)                        0
# Mean Anomoly (deg)                          0
# Perihelion Distance (AU)                    0
# Aphelion Distance (AU)                      0
# Orbital Period (yr)                         0
# Minimum Orbit Intersection Distance (AU)    0
# Orbital Reference                           0
# Asteroid Magnitude                          0
# Classification                              0
# Hazardous                                   0
# dtype: int64

# %% [markdown]
# To predict is it Hazardous ?

# %%
x=df.iloc[:,1:-2]

# %%
x
# Out:
#        Epoch (TDB)  Orbit Axis (AU)  Orbit Eccentricity  \
# 0            57800           1.4579              0.2226
# 1            57800           2.6385              0.5479
# 2            57800           2.4787              0.5671
# 3            57800           2.6628              0.5338
# 4            57800           1.9191              0.4356
# ...            ...              ...                 ...
# 15630        57800           1.4096              0.2946
# 15631        57789           2.2612              0.4429
# 15632        57800           1.5131              0.3275
# 15633        57793           1.8815              0.4646
# 15634        57800           2.8043              0.6672
#
#        Orbit Inclination (deg)  Perihelion Argument (deg)  \
# 0                      10.8277                   178.8050
# 1                      11.5822                   156.1409
# 2                       9.3561                   350.3482
# ...

# %%
y=df[['Hazardous']]

# %%
y
# Out:
#                          Hazardous
# 0               Safe - no worries.
# 1               Safe - no worries.
# 2               Safe - no worries.
# 3               Safe - no worries.
# 4               Safe - no worries.
# ...                            ...
# 15630           Safe - no worries.
# 15631           Safe - no worries.
# 15632           Safe - no worries.
# 15633           Safe - no worries.
# 15634  Warning ! collision  threat
#
# [15634 rows x 1 columns]

# %% [markdown]
# RF

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=128)

# %%
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier(n_estimators=50)
r.fit(x_train,y_train)
# Out:
# C:\Users\debna\AppData\Local\Temp\ipykernel_9920\2627107269.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   r.fit(x_train,y_train)
# RandomForestClassifier(n_estimators=50)

# %%
r.score(x_train,y_train)
# Out:
# 1.0

# %%
r.score(x_test,y_test)
# Out:
# 1.0

# %%
r.predict([[57800,1.2453,0.3353,13.3375,276.893,337.208,104.1556,0.8277,1.66,1.39,0.0307,449,15.6]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Warning ! collision  threat'], dtype=object)

# %%
r.predict([[57800,1.08,0.467,16.0951,325.2523,212.9288,29.5707,0.5757,1.58,1.12,0.1566,123,16.84]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Safe - no worries.'], dtype=object)

# %% [markdown]
# DL

# %%
# Convert labels to numerical format using LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# Define your deep learning model
model = Sequential([
    Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(len(label_encoder.classes_), activation='softmax')  # Output layer with softmax activation for multi-class classification
])

# Compile the model with sparse categorical cross-entropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\debna\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7791 - loss: 479.6538 - val_accuracy: 0.8823 - val_loss: 105.0366
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8010 - loss: 56.9041 - val_accuracy: 0.8823 - val_loss: 74.2515
# Epoch 3/50
# ...

# %%
input_data = [[57800,1.08,0.467,16.0951,325.2523,212.9288,29.5707,0.5757,1.58,1.12,0.1566,123,16.84]]

# Convert input data to numpy array if necessary
input_data = array(input_data)

# Preprocess input data if necessary (e.g., scaling)
# Make predictions
predictions = model.predict(input_data)

# Decode predictions back to string labels
predicted_labels = label_encoder.inverse_transform(predictions.argmax(axis=1))


predicted_labels
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# array(['Safe - no worries.'], dtype=object)

# %% [markdown]
# Let's  predict asteroid classification

# %%
x=df.iloc[:,1:-2]

# %%
x
# Out:
#        Epoch (TDB)  Orbit Axis (AU)  Orbit Eccentricity  \
# 0            57800           1.4579              0.2226
# 1            57800           2.6385              0.5479
# 2            57800           2.4787              0.5671
# 3            57800           2.6628              0.5338
# 4            57800           1.9191              0.4356
# ...            ...              ...                 ...
# 15630        57800           1.4096              0.2946
# 15631        57789           2.2612              0.4429
# 15632        57800           1.5131              0.3275
# 15633        57793           1.8815              0.4646
# 15634        57800           2.8043              0.6672
#
#        Orbit Inclination (deg)  Perihelion Argument (deg)  \
# 0                      10.8277                   178.8050
# 1                      11.5822                   156.1409
# 2                       9.3561                   350.3482
# ...

# %%
y=df[['Classification']]

# %%
y
# Out:
#         Classification
# 0        Amor Asteroid
# 1        Amor Asteroid
# 2        Amor Asteroid
# 3        Amor Asteroid
# 4        Amor Asteroid
# ...                ...
# 15630  Apollo Asteroid
# 15631    Amor Asteroid
# 15632    Amor Asteroid
# 15633  Apollo Asteroid
# 15634  Apollo Asteroid
#
# [15634 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=128)

# %%
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier(n_estimators=100)
r.fit(x_train,y_train)
# Out:
# C:\Users\debna\AppData\Local\Temp\ipykernel_9920\2167681452.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   r.fit(x_train,y_train)
# RandomForestClassifier()

# %%
r.score(x_train,y_train)
# Out:
# 1.0

# %%
r.score(x_test,y_test)
# Out:
# 0.9982946066936688

# %%
r.predict([[57800,1.08,0.467,16.0951,325.2523,212.9288,29.5707,0.5757,1.58,1.12,0.1566,123,16.84]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Apollo Asteroid'], dtype=object)

# %%
r.predict([[57800,2.235,0.515,6.3757,213.5669,241.3239,298.9296,1.084,3.39,3.34,0.1153,41,19.4]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Amor Asteroid'], dtype=object)
