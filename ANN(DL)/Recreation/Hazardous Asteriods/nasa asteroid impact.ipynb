# %%
# Import required libraries
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
from pandas import  *
from numpy import *
from seaborn import *
from matplotlib.pyplot import *
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
df=read_csv('nasa.csv')

# %%
df
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080              21.600            0.127220
# 1              3723955  3723955              21.300            0.146068
# 2              2446862  2446862              20.300            0.231502
# 3              3092506  3092506              27.400            0.008801
# 4              3514799  3514799              21.600            0.127220
# ...                ...      ...                 ...                 ...
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %%
df.isnull().sum()
# Out:
# Neo Reference ID                0
# Name                            0
# Absolute Magnitude              0
# Est Dia in KM(min)              0
# Est Dia in KM(max)              0
# Est Dia in M(min)               0
# Est Dia in M(max)               0
# Est Dia in Miles(min)           0
# Est Dia in Miles(max)           0
# Est Dia in Feet(min)            0
# Est Dia in Feet(max)            0
# Close Approach Date             0
# Epoch Date Close Approach       0
# Relative Velocity km per sec    0
# Relative Velocity km per hr     0
# Miles per hour                  0
# Miss Dist.(Astronomical)        0
# Miss Dist.(lunar)               0
# Miss Dist.(kilometers)          0
# Miss Dist.(miles)               0
# Orbiting Body                   0
# Orbit ID                        0
# Orbit Determination Date        0
# Orbit Uncertainity              0
# Minimum Orbit Intersection      0
# Jupiter Tisserand Invariant     0
# Epoch Osculation                0
# ...

# %%
df=df.drop(columns='Close Approach Date')
df=df.drop(columns='Epoch Date Close Approach')
df=df.drop(columns='Orbiting Body')
df=df.drop(columns='Orbit Determination Date')

# %%
x=df.iloc[:,2:-2]

# %%
x.columns
# Out:
# Index(['Absolute Magnitude', 'Est Dia in KM(min)', 'Est Dia in KM(max)',
#        'Est Dia in M(min)', 'Est Dia in M(max)', 'Est Dia in Miles(min)',
#        'Est Dia in Miles(max)', 'Est Dia in Feet(min)', 'Est Dia in Feet(max)',
#        'Relative Velocity km per sec', 'Relative Velocity km per hr',
#        'Miles per hour', 'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)',
#        'Miss Dist.(kilometers)', 'Miss Dist.(miles)', 'Orbit ID',
#        'Orbit Uncertainity', 'Minimum Orbit Intersection',
#        'Jupiter Tisserand Invariant', 'Epoch Osculation', 'Eccentricity',
#        'Semi Major Axis', 'Inclination', 'Asc Node Longitude',
#        'Orbital Period', 'Perihelion Distance', 'Perihelion Arg',
#        'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly', 'Mean Motion'],
#       dtype='object')

# %%
y=df[['Hazardous']]

# %%
y
# Out:
#       Hazardous
# 0          True
# 1         False
# 2          True
# 3         False
# 4          True
# ...         ...
# 4682      False
# 4683      False
# 4684      False
# 4685      False
# 4686      False
#
# [4687 rows x 1 columns]

# %% [markdown]
# RF

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=128)

# %%
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier(n_estimators=100)
r.fit(x_train,y_train)
# Out:
# C:\Users\debna\AppData\Local\Temp\ipykernel_10688\2167681452.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   r.fit(x_train,y_train)
# RandomForestClassifier()

# %%
r.score(x_train,y_train)
# Out:
# 1.0

# %%
r.score(x_test,y_test)
# Out:
# 0.9985785358919688

# %%
r.predict([[19.6,0.3195618867,0.7145621017,319.5618867213,714.5621017269,0.1985664891,0.4440081677,1048.4314204307,2344.3639258298,790156800000,10.8088415879,38911.829716462,24178.2977479872,0.392783196,152.7926635742,58759532,36511480,43,.272213,4.724,2458000.5,.5634411100746358,1.323532161963902,17.92774837902645,178.9719525667907,556.1605444942963,.5777997314074783,198.1459598526758,2.069264592520325,2458009.402591357977,354.237396160877,.6472951085146458]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([False])

# %% [markdown]
# DL

# %%
# Convert labels to numerical format using LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# Define your deep learning model
model = Sequential([
    Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(len(label_encoder.classes_), activation='softmax')  # Output layer with softmax activation for multi-class classification
])

# Compile the model with sparse categorical cross-entropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=50 ,batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\debna\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6806 - loss: 273397.7812 - val_accuracy: 0.7729 - val_loss: 10859.8008
# Epoch 2/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7098 - loss: 64144.7852 - val_accuracy: 0.2004 - val_loss: 254950.4844
# Epoch 3/50
# ...

# %% [markdown]
# 84 %  accuracy

# %%
input_data = [[19.6,0.3195618867,0.7145621017,319.5618867213,714.5621017269,0.1985664891,0.4440081677,1048.4314204307,2344.3639258298,790156800000,10.8088415879,38911.829716462,24178.2977479872,0.392783196,152.7926635742,58759532,36511480,43,.272213,4.724,2458000.5,.5634411100746358,1.323532161963902,17.92774837902645,178.9719525667907,556.1605444942963,.5777997314074783,198.1459598526758,2.069264592520325,2458009.402591357977,354.237396160877,.6472951085146458]]

# Convert input data to numpy array if necessary
input_data = array(input_data)

# Preprocess input data if necessary (e.g., scaling)
# Make predictions
predictions = model.predict(input_data)

# Decode predictions back to string labels
predicted_labels = label_encoder.inverse_transform(predictions.argmax(axis=1))


predicted_labels
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# array([False])
