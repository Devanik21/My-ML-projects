# %%
from pandas import  *
from numpy import *
from seaborn import *
from matplotlib.pyplot import *
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
# Import required libraries
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
df=read_csv('wine.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
x=df.iloc[:,:-1]

# %%
x.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
y=df[['quality']]

# %%
y
# Out:
#              quality
# 0      lower quality
# 1      lower quality
# 2      lower quality
# 3     finest quality
# 4      lower quality
# ...              ...
# 1594   lower quality
# 1595  finest quality
# 1596  finest quality
# 1597   lower quality
# 1598  finest quality
#
# [1599 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=128)

# %%
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier(n_estimators=50)
r.fit(x_train,y_train)
# Out:
# C:\Users\debna\AppData\Local\Temp\ipykernel_17884\2627107269.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   r.fit(x_train,y_train)
# RandomForestClassifier(n_estimators=50)

# %%
r.score(x_train,y_train)
# Out:
# 1.0

# %%
r.score(x_test,y_test)
# Out:
# 0.7895833333333333

# %%
r.predict([[8,0.5,0.02,2.0,0.073,9,18.0,0.9,3,0.57,9]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['lower quality'], dtype=object)

# %% [markdown]
# Let's try DL

# %% [markdown]
# Actual accuracy is 76 %

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Define your deep learning model for binary classification
input_layer = Input(shape=(x_train.shape[1],))
dense_1 = Dense(128, activation='relu')(input_layer)
dense_2 = Dense(64, activation='relu')(dense_1)
dense_3 = Dense(32, activation='relu')(dense_2)
output = Dense(1, activation='sigmoid', name='binary_output')(dense_3)

model = Model(inputs=input_layer, outputs=output)

# Compile the model with binary cross-entropy loss
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=1000, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/3000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5026 - loss: 1.3691 - val_accuracy: 0.6375 - val_loss: 0.6495
# Epoch 2/3000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5889 - loss: 0.6675 - val_accuracy: 0.6438 - val_loss: 0.6422
# Epoch 3/3000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6462 - loss: 0.6319 - val_accuracy: 0.6281 - val_loss: 0.6333
# Epoch 4/3000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6491 - loss: 0.6268 - val_accuracy: 0.6375 - val_loss: 0.6322
# Epoch 5/3000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6368 - loss: 0.6290 - val_accuracy: 0.6313 - val_loss: 0.6335
# Epoch 6/3000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6082 - loss: 0.6554 - val_accuracy: 0.6531 - val_loss: 0.6655
# Epoch 7/3000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6219 - loss: 0.6360 - val_accuracy: 0.6250 - val_loss: 0.6268
# Epoch 8/3000
# ...

# %%
input_data = [[7.9,0.6,0.06,1.6,0.069,15.0,59.0,0.9964,3.3,0.46,9.4]]

# Convert input data to numpy array if necessary
input_data = array(input_data)
       
# Preprocess input data if necessary (e.g., scaling)
# Make predictions
predictions = model.predict(input_data)

# Decode predictions back to string labels
predicted_labels = label_encoder.inverse_transform(predictions.argmax(axis=1))


predicted_labels
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# array(['finest quality'], dtype=object)

# %%
input_data = [[11,0.28,0.5,1.9,0.07,17,60.0,0.9,3.1,0.5,9]]

# Convert input data to numpy array if necessary
input_data = array(input_data)
       
# Preprocess input data if necessary (e.g., scaling)
# Make predictions
predictions = model.predict(input_data)

# Decode predictions back to string labels
predicted_labels = label_encoder.inverse_transform(predictions.argmax(axis=1))


predicted_labels
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# array(['finest quality'], dtype=object)
