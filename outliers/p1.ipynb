# %%
from pandas import  *
from numpy import *
from seaborn import *
from matplotlib.pyplot import *
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
df=read_csv('emp.csv')
df
# Out:
#      id             name gender  age  salary
# 0  1001       Ganesh Rao      M   25      20
# 1  1002          Lakshmi      F   22      20
# 2  1003      Vinod Kumar      M   30      22
# 3  1004           Neelam      F   33      30
# 4  1005          Reethu       F   21      19
# 5  1006    Gaurav Pandey      M   40      25
# 6  1007         Kulkarni      M   30      24
# 7  1008  Vishal Muhammad      M   29      19
# 8  1009      Meena Singh      F   25      21
# 9  1010   Ankhit Chandra      M   40      26

# %%
scatter(df['id'],df['age'])

# %%
scatter(df['id'],df['salary'])

# %%
df=read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(subset=['Embarked'], inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1=df.drop('Cabin',axis=1)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2=df1.drop('Age',axis=1)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %% [markdown]
# Now, there are no missing values

# %% [markdown]
# or u can replace nan by mean / median -

# %% [markdown]
# import pandas as pd
#
# # Assuming df is your DataFrame
# df = pd.read_csv('titanic.csv')
#
# # Fill NaN values in the 'Age' column with the median
# median_age = df['Age'].median()
# df['Age'].fillna(median_age, inplace=True)
#
# # Now, df contains the 'Age' column with NaN values filled with the median

# %%
df=read_csv('CARS.csv')
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
# Fill NaN values in the 'Age' column with the median
median_age = df['Cylinders'].median()
df['Cylinders'].fillna(median_age, inplace=True)

# Now, df contains the 'Age' column with NaN values filled with the median

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
pairplot(data=df,hue='Origin')
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\debna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\debna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
scatter(df['MSRP'],df['Horsepower'])

# %% [markdown]
# No outlier, no missing values , perfect data

# %%
df=read_csv('Solid_Waste_Generation___Recycling.csv')
df
# Out:
#     Year  Agricultural Organics  Aluminum Cans  Anti-freeze  \
# 0   2000                      0          17944         2475
# 1   2001                      0          12540         4157
# 2   2002                      0          12718         4506
# 3   2003                      0          17608         4722
# 4   2004                      0          16010         8050
# 5   2005                      0          15441         8767
# 6   2006                      0          14951         7507
# 7   2007                      0          14005         7055
# 8   2008                  31800          12842         6586
# 9   2009                  45431          21098         5194
# 10  2010                  55689          13655         4783
# 11  2011                  76645          13115         4872
# 12  2012                 102732          13635         6797
# 13  2013                  97270          16679         4804
# 14  2014                  66660          14309         4955
#
# ...

# %%
# Fill NaN values in the 'Age' column with the median
median_age = df['Tires (Baled)'].median()
df['Tires (Baled)'].fillna(median_age, inplace=True)

# Now, df contains the 'Age' column with NaN values filled with the median

# %%
# Fill NaN values in the 'Age' column with the median
median_age = df['Yard Debris and Food (mixed)'].median()
df['Yard Debris and Food (mixed)'].fillna(median_age, inplace=True)

# Now, df contains the 'Age' column with NaN values filled with the median

# %%
# Fill NaN values in the 'Age' column with the median
median_age = df['Tires Disposed in Out-of-State Landfills'].median()
df['Tires Disposed in Out-of-State Landfills'].fillna(median_age, inplace=True)

# Now, df contains the 'Age' column with NaN values filled with the median

# %%
df
# Out:
#     Year  Agricultural Organics  Aluminum Cans  Anti-freeze  \
# 0   2000                      0          17944         2475
# 1   2001                      0          12540         4157
# 2   2002                      0          12718         4506
# 3   2003                      0          17608         4722
# 4   2004                      0          16010         8050
# 5   2005                      0          15441         8767
# 6   2006                      0          14951         7507
# 7   2007                      0          14005         7055
# 8   2008                  31800          12842         6586
# 9   2009                  45431          21098         5194
# 10  2010                  55689          13655         4783
# 11  2011                  76645          13115         4872
# 12  2012                 102732          13635         6797
# 13  2013                  97270          16679         4804
# 14  2014                  66660          14309         4955
#
# ...

# %%
scatter(df['Year'],df['Aluminum Cans'])
title('  outlier detection')
# Out:
# Text(0.5, 1.0, '  outlier detection')

# %%
#pairplot(data=df,hue='Year')
